# %% [markdown]
# #### HTML의 구조  및 태그
# - 구조
#  - \<!Doctype html> : HTML5 문서를 선언하는 구문
#  - \<html></html> : HTML 문서의 시작과 끝
#  - \<head></head> : CSS, JavaScript, meta, title 정보들을 설정
#  - \<body></body> : 실제 홈페이지 화면을 나타내는 부분
#
# - 요소 구조
#  - HTML 요소는 여러 속성들을 가질 수 있으며 속성들은 해당 요소에 대한 추가 정보를 제공
#  - 시작 태그\(< >)로 시작해서 종료 태그(</>)로 끝남
#  - 요소 안에 다른 요소를 작성할 수 있음
#  <img src = './dataset/html요소구조.jpg' STYLE = 'width:50px;'>

# %% [markdown]
# ### HTML 태그
# - p 태그를 이용하여 문단 작성
# - h 태그를 이용하여 폰트 크기 설정
# - ul(unordered list)과 ol(ordered list) 태그로 리스트 작성, 리스트 각각의 요소는 li(항목 나열) 태그로 표시
# - table 태그는 thead, tbody를 가질 수 있으며 표를 표현 : tr 행, th(가운데 정렬,굵은 글씨체),td 각 행의 컬럼
# - input 태그와 button 태그 : 데이터를 넣는 폼과 페이지 조작 버튼 생성
# - select # select 태그로 선택 리스트 생성
# - a 태그로 다른 페이지로 이동. 상대경로(내가 있는 경로부터의 경로), 절대경로(항상 같은 url)
# - img 태그로 이미지 포함 : src(이미지 붙임), alt(이미지 대체)
# - span 태그로 p태그 처럼 글을 추가. span 태그는 옆으로 나열. br 태그 사용하여 p 태그처럼 사용
# - div 태그는 화면 레이아웃을 잡는 역할 : 하위 태그들의 영역을 잡아줌

# %% [markdown]
# ### CSS
# - CSS로 웹 사이트를 꾸며주기 위해 해당 태그에 접근하는 방식을 크롤러에서도 사용.
# - selector : CSS로 꾸미기 위해 특정 요소에 접근하는 것을 셀렉터라고 함.
# - html 파일을 만들었다면 각각의 태그에 다르게 css 를 설정 할 것입니다. 이 때, 어느 요소에 스타일을 적용할지 알려주는 방식이 바로 css 선택자 입니다.
# - 태그를 이용하여 접근하면 태그는 전부 CSS 효과가 적용
# - class를 이용하면 원하는 요소만 CSS 효과 적용할 수 있고 원하는 요소만 수집할 수 있음.
# - id는 class와 다르게 id값이 고유해야 함(id는 한페이지에 하나만 존재해야 함)
# - 부모 태그와 자식 태그를 나열하여 복잡한 셀렉터를 생성<br>
# - 참조 url https://ssungkang.tistory.com/entry/css-css-%EC%84%A0%ED%83%9D%EC%9E%90selector-%EC%9D%98-%EC%A2%85%EB%A5%98%EC%99%80-%EC%98%88%EC%8B%9C https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors https://www.nextree.co.kr/p8468/

# %% [markdown]
# ### JavaScript
# - 웹 사이트의 기능을 넣어줌. script 태그를 이용하여 작성. head or body 하단에 위치
# - js를 이용하여 HTML 코드를 생성. 크롤러로 분석하기 가장 어려운 부분임
# - DOM(Document Object Model)이란 HTML을 시각적으로 쉽게 표현하기 위해 만든 객체로 크롤러 만들 때 중요
# - 데이터를 수집하기 위해 DOM을 이용해 데이터에 접근한 후 해당 데이터 수집
# - 웹 브라우저는 HTML 코드를 가져온 후 JavaScript를 실행시킨 결과를 보여줌
# - 소스 보기 페이지에 수집하고자 하는 요소가 없다면 네트워크 탭을 이용, 서버에서 데이터를 받아오는 지 확인
# - 그렇지 않은 경우 셀레니움을 사용하여 해결<br>
# - 참조 url http://www.tcpschool.com/javascript/js_dom_document

# %%
# 인덱싱
text = 'k=digital training 5기'
text1 = 'abc'
print(text[0])
print(text[-1])
print(text1.replace('a','A'))
print(text1.capitalize()) # 첫글자만 대문자
print(text1.upper()) # 모두 대문자
print(text.capitalize())

# %% [markdown]
# ### strip 공백 제거
# - strip : 양쪽 문자열에 공백이나 인자가된 문자열의 모든 조합을 제거
# - rstrip : 문자열에 오른쪽 공백이나 인자가된 문자열의 모든 조합을 제거
# - lstrip : 문자열에 왼쪽 공백이나 인자가된 문자열의 모든 조합을 제거

# %%
print(' apple'.lstrip())     # 인자가 없을 경우 왼쪽 공백 제거

print('apple'.lstrip('ap'))   # 왼쪽으로 a, p의 문자열의 모든 조합을 제거

# %%
print('apple '.rstrip())        # 인자가 없을 경우 오른쪽 공백 제거

print('apple'.rstrip('lep'))   # 오른쪽으로 l, e, p의 문자열의 모든 조합을 제거

# %%
print(' apple '.strip())    # 인자가 없을 경우 양쪽 공백 제거

print('apple'.strip('ae'))  # 양쪽끝에 a, e의 문자열의 모든 조합을 제거

# %%
# [과제]'K-Digital Training 5기'를 출력하세요

# %%
text1 = "   <k-digital training 5기>   "
text2 = ';'

# %%
# Q. <k-digital training 5기>; 를 출력하세요
print(text1.strip()+text2) # 양쪽 공백 제거 후 이어 붙이기

# %%
# Q. <k-digital training 5기>   ; 를 출력하세요
print(text1.lstrip()+text2) # 왼쪽 공백 제거 후 이어 붙이기

# %%
# Q.    <k-digital training 5기>; 를 출력하세요
print(text1.rstrip()+text2) # 오른쪽 공백 제거 후 이어 붙이기

# %%
text = "<title>k-digital training 5기</title>"

# %%
# Q. text를 아래와 같이 출력하세요
# <div>k-digital training 5기</title>
text.replace('<title','<div')

# %%
# Q. text를 아래와 같이 출력하세요
# <div>k-digital training 5기</div>
text.replace('title','div')

# %% [markdown]
# ### 정규표현식

# %%
# \g<그룹이름>을 사용하면 정규식의 그룹 이름을 참조할 수 있다.
import re
data = """
park 800905-1049118
kim  700905-1059119
"""

pat = re.compile('(\d{6})[-]\d{7}')
print(pat.sub('\g<1>-*******', data))

# re.sub(pattern, 바꿀 str, 기존 str)
# 기존 str에서 pattern을 찾아 바꿀 str으로 교체하는 함수
# pattern에서 group을 지정했다면 바꿀 str에서 <\\num>을 사용하여 해당 group의 str을 그대로 사용 가능

# %%
import re
text = ('111<head>안녕하세요</head>22')
body = re.search('<head>안녕하세요</head>',text) # text에서 <head>안녕하세요</head> 이 부분 search
body = body.group()
print(body)

# %%
a = re.search('<head>.+</head>',text)
a.group()

# %%
t = re.compile('[^0-9]+').search(text) # 숫자가 아닌것 1개 이상
t.group()

# %%
body = re.search(r'\D+',text) # 숫자가 아닌 것과 매치, [^0-9]와 동일한 표현식
body.group()

# %%
body = re.compile('[가-힣]+').search(text)
body.group()

# %%
a = re.search('안녕하세요',text).group()
a

# %%
text = "<head>안녕하세요...<title>k-digital training 5기</title> 반갑습니다...</head>"

# %%
# Q. <title>k-digital training 5기</title> 을 출력하세요
import re
t = re.search('<title>.*</title>',text) 
print(t.group())

# %%
# Q. k-digital training 5기 을 출력하세요.
# group(0) 매치된 전체 문자열, group(1) 매치된 첫번째 그룹에 해당하는 문자열
t = re.search('<title>(.+)</title>', text)
t.group(1)

# %%
t = t.group()
t = re.sub('<.+?>','',t) # re.sub(pattern, 바꿀 str, 기존 str)
t

# %% [markdown]
# ### requests 모듈
# - pip install requests 명령어로 설치
# - http는 요청과 응답으로 이루어져 있음
# - 요청
#   - GET : 정보를 가져오기 위해 요청
#   - POST : 새로운 정보를 보내기 위해 요청
#   - PUT : 수정할 정보를 보내기 위해 요청
#   - DELETE : 정보를 삭제하기 위해 요청
# - 응답
#   - 1XX : 요청을 받았고 작업 진행 중
#   - 2XX : 사용자의 요청이 성공적으로 수행됨
#   - 3XX : 요청은 완료되었으나 리다이렉션이 필요
#   - 4XX : 사용자의 요청이 잘못됨
#   - 5XX : 서버 오류가 발생함

# %%
# !pip install requests

# %%
import requests # 외장 라이브러리 사용
URL = 'http://naver.com'
response = requests.get(URL)
response.status_code
html_data = response.text
html_data
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
html_data.find('네이버')

# %%
print(html_data[365:368])

# %%
import re
content = re.search('네이버',html_data)
content.group()

# %%
import re
content1 = re.search('([가-힣]+)',html_data)
content1.group()

# %%
html_data.find('<meta property=')
print(html_data[390:480])

# %%
content0 = html_data.split('<meta property=')[0]
content1 = html_data.split('<meta property=')[1]
print(content0,'\n')
print(content1)

# %%
content = re.search('네이버+',content1)
content.group()

# %%
URL = 'https://search.naver.com/search.naver'
params = {'query':'AI'}
response = requests.get(URL, params=params)
response.status_code
response.text

# %%
URL = 'https://comic.naver.com/webtoon/detail'
params = {'titleId':784255,'no':29,'weekday':'wed'}
response = requests.get(URL,params=params)
response.status_code # 온라인 서비스를 HTTP로 호출하면 상태 코드를 응답받게 됩니다.
response.text          # 일반적으로 이 상태 코드를 보고 요청이 잘 처리되었는지 문제가 있는지 알 수가 있습니다.
                        # 상태 코드는 응답 객체의 status_code 속성을 통해 간단하게 얻을 수 있습니다.

# %%
# Q. 네이버 사이트에서 '공지사항' 출력(파이썬 인덱싱, 함수 / 정규표현식)
URL = 'http://naver.com'
response = requests.get(URL)
response.status_code
naver = response.text #  html에서 텍스트만 뽑아낼 수 있음
t = re.search('공지사항',naver)
t.group()
# Out:
# '공지사항'

# %%
url = 'https://naver.com'
res = requests.get(url) # url얻기
res.status_code
r = res.text

# 인덱싱
rr = r.find('공지사항')
display(rr, r[rr:(rr+4)])

# %%
# [과제] 네이버 홈페이지에 있는 ['메일','카페','블로그','지식iN','쇼핑']을 출력하세요

# %%
from bs4 import BeautifulSoup
import requests
URL = 'http://naver.com'
response = requests.get(URL)
response.status_code
naver = response.text
soup = BeautifulSoup(naver,'html.parser')
a = soup.select('#NM_FAVORITE > div.group_nav > ul.list_nav.type_fix > li.nav_item> a',limit=5)
#NM_FAVORITE > div.group_nav > ul.list_nav.type_fix > li:nth-child(2) > a  --> copy selector
li = []
for i in a:
    li.append(i.text)
li
# Out:
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %% [markdown]
# ### BeautifulSoup 모듈
#
# - 홈페이지 내 데이터를 쉽게 추출할 수 있게 해주는 파이썬 외부 라이브러리
# - 웹 문서 내 수많은 HTML 태그들을 parser를 활용해 사용하기 편한 파이썬 객체로 만들어 제공
# - 웹 문서 구조를 알고 있다면 편하게 데이터를 뽑아 활용할 수 있음
# - BS는 HTML 문서를 태그를 기반으로 구조화하여 태그로 원하는 데이터를 찾아가는 형식
#
# - find() : HTML의 해당 태그에 대한 첫번째 정보를 가져옴
#   - find(속성='값') : HTML 해당 속성과 일치하는 값에 대한 첫번째 정보를 가져옴
# - find_all(), findAll
#   - HTML의 해당 태그에 대한 모든 정보를 리스트 형식으로 가져옴. limit 옵션으로 개수 지정 가능
#   - CSS 속성으로 필터링(class_로 클래스를 직접 사용 혹은 attrs에서 속성 = 값으로 필터링)
# - select_one(), select()
#   - CSS 선택자를 활용하여 원하는 정보를 가져옴(태그를 검색하는 find, find_all과 비슷함)
#   - class는 점(.)으로, id는 #로 표시

# %%
pip install requests beautifulsoup4

# %%
html_doc = """
<html lang="en">
<head><title>crawl</title></head>
<body>
<p class="a" align="center"> text1</p>
<p class="b" align="center"> text2</p>
<p class="c" align="center"> text3</p>
<div><img src="/source" width="300" height="200"></div>
</body>
</html>
"""
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser') 
print(soup.prettify()) # html문서처럼 구조화 시켜줌
# Out:
# <html lang="en">
#  <head>
#   <title>
#    crawl
#   </title>
#  </head>
#  <body>
#   <p align="center" class="a">
#    text1
#   </p>
#   <p align="center" class="b">
#    text2
#   </p>
#   <p align="center" class="c">
#    text3
#   </p>
#   <div>
#    <img height="200" src="/source" width="300"/>
#   </div>
#  </body>
# </html>

# %%
URL = 'http://naver.com'
req = requests.get(URL) # req 변수에는 해당 url로 요청한 결과 값이 들어가 있는 상태이다.
html = req.text # req 변수에 html 코드를 보고 싶다면 req.text 라고 작성하면 html 코드를 볼 수 있다.
html.find('blind')
html[9800:10000]
# Out:
# 'er.com/banner/details/quicksearch?=main&wpid=RydDy7"\ndata-clk="dropbanner1a"\n></a\n><i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i\n><img\nsrc="https://static-whale.pstatic.net/'

# %%
soup = BeautifulSoup(html,'html.parser')
result = soup.find(class_='blind')
result.text
# Out:
# 'NAVER whale'

# %%
html = """
<html><body>
  <h1 id="title">스크레이핑이란?</h1>
  <p id = "body">웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
  <p>원하는 부분을 하나 더 추출하는 것</p>
</body></html>
"""
print(type(html)) # string type

soup = BeautifulSoup(html, 'html.parser')

body = soup.find(id = "body")
title = soup.find(id = 'title')

body.text # 출력 --> 웹 페이지를 분석하는것
title.string # 출력 --> 스크래핑이란?
# Out:
# <class 'str'>
# '스크레이핑이란?'

# %%
h1 = soup.html.body.h1.string
h1
# Out:
# '스크레이핑이란?'

# %%
p1 = soup.html.body.p
p1.string
# Out:
# '웹 페이지를 분석하는 것'

# %%
# find_all()
soup = BeautifulSoup(html, 'html.parser')
texts = soup.find_all('p') # 태그 p 모두 찾기
for text in texts: # for문 돌려서 p태그 안에 있는 텍스트 찾기
    print(text.text)
# Out:
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것
# 원하는 부분을 하나 더 추출하는 것

# %%
html = """
<html><body>
  <ul>
    <li><a href="http://www.naver.com">naver</a></li>
    <li><a href="http://www.daum.net">daum</a></li>
  </ul>
</body></html>
"""
soup = BeautifulSoup(html,'html.parser')
links = soup.find_all('a') # 리스트형태로 반환되므로 출력시 for문 사용
# links
for a in links:
    print(a.text,'>', a.get('href')) # a에서의 text만 a에서의 href 출력
# Out:
# naver > http://www.naver.com
# daum > http://www.daum.net

# %%
import urllib.request as req # 내장 라이브러리

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res = req.urlopen(url) # res 변수에는 해당 url로 요청한 결과 값이 들어가 있는 상태이다.
soup = BeautifulSoup(res,'html.parser')  # BeautifulSoup 생성자에서 res 파싱하고 
                                            # 결과를 BeautifulSoup 객체로 반환한다.
    
title = soup.find('title').string # title 문자열로 반환
title
# Out:
# '기상청 육상 중기예보'

# %%
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
title = soup.find('title').string
wf = soup.find('wf').string # find(name, attrs, recursive, string, **kwargs)
            # 조건에 맞는 태그를 가져옵니다. 만약 조건에 맞는 태그가 1개 이상이면 가장 첫 번째 태그를 가져옵니다.
print(title,'\n')
print(wf)
# Out:
# 기상청 육상 중기예보
#
# ○ (하늘상태) 18일(금)~19일(토) 전국 구름많겠습니다. 그 밖의 기간에는 대체로 맑겠습니다.<br />○ (기온) 이번 예보기간 아침 기온은 -12~3도, 낮 기온은 -2~10도로 오늘(12일, 아침최저기온 -4~5도, 낮최고기온 8~14도)보다 낮겠습니다.<br />          특히, 16일(수)~18일(금), 21일(월)은 찬 공기가 남하하여 다른 예보 기간보다 춥겠습니다.<br />○ (해상) 16일(수)~17일(목) 동해상에서는 물결이 2.0~4.0m로 매우 높게 일겠습니다.

# %%
# bs4와 정규표현식 활용
import re
res = req.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text

# findall -> HTML의 해당 태그에 대한 모든 정보를 리스트 형식으로 가져오기 때문에
' '.join(re.findall('[0-9가-힣]+',wf))  # ' '.join함수 써서 이어줌 -> 매끄럽게 출력
# Out:
# '하늘상태 18일 금 19일 토 전국 구름많겠습니다 그 밖의 기간에는 대체로 맑겠습니다 기온 이번 예보기간 아침 기온은 12 3도 낮 기온은 2 10도로 오늘 12일 아침최저기온 4 5도 낮최고기온 8 14도 보다 낮겠습니다 특히 16일 수 18일 금 21일 월 은 찬 공기가 남하하여 다른 예보 기간보다 춥겠습니다 해상 16일 수 17일 목 동해상에서는 물결이 2 0 4 0 로 매우 높게 일겠습니다'

# %%
# 정규표현식 
# ? -> 문자가 있거나 없거나 둘 다 매치 되는 경우입니다. ->  ab?c : “a + b(있어도 되고 없어도 된다) + c”
# Dot(.) - > a와 b라는 문자 사이에 어떤 문자가 들어가도 모두 매치된다는 의미이다. -> "a + 모든문자 + b" 
text = re.findall('[^ a-zA-Z0-9]?[0-9가-힣]+[^ a-zA-Z0-9]?',wf)
print(text)
# Out:
# ['(하늘상태)', '18일(', '금)', '~19일(', '토)', '전국', '구름많겠습니다.', '그', '밖의', '기간에는', '대체로', '맑겠습니다.', '(기온)', '이번', '예보기간', '아침', '기온은', '-12~', '3도,', '낮', '기온은', '-2~', '10도로', '오늘(', '12일,', '아침최저기온', '-4~', '5도,', '낮최고기온', '8~', '14도)', '보다', '낮겠습니다.', '특히,', '16일(', '수)', '~18일(', '금)', '21일(', '월)', '은', '찬', '공기가', '남하하여', '다른', '예보', '기간보다', '춥겠습니다.', '(해상)', '16일(', '수)', '~17일(', '목)', '동해상에서는', '물결이', '2.', '0~', '4.', '0', '로', '매우', '높게', '일겠습니다.']

# %%
res = req.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# '(하늘상태) 18일(금)~19일(토) 전국 구름많겠습니다. 그 밖의 기간에는 대체로 맑겠습니다.(기온) 이번 예보기간 아침 기온은 -12~3도, 낮 기온은 -2~10도로 오늘(12일, 아침최저기온 -4~5도, 낮최고기온 8~14도)보다 낮겠습니다. 특히, 16일(수)~18일(금) 21일(월)은 찬 공기가 남하하여 다른 예보 기간보다 춥겠습니다.(해상) 16일(수)~17일(목) 동해상에서는 물결이 2.0~4.0m로 매우 높게 일겠습니다.'

# %%
# [과제] wf 태그는 모두 출력

# %%
url = 'https://naver.com'
text = requests.get(url).text
text

# %%
import urllib
url = 'https://naver.com'
response = urllib.request.urlopen(url)
byte_data = response.read() # response.read() byte 형식으로 url 읽어옴
html = byte_data.decode('utf-8') # 변환
soup = BeautifulSoup(html,'html.parser')
print(soup.find('a'))
print(soup.find(class_='blind'))
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>
# <span class="blind">NAVER whale</span>

# %%
 # 모든 a 태그 검색 -> limit = 0
soup.find_all('a', limit=2)  # a태그 두 개만 가져옴.
soup.find_all('a', limit=2)[0] # 두개 가져온것 중에서 0번째 인덱스 출력
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>

# %%
soup.find_all('span',class_='blind')[0:3] # 인덱스 0~2까지 출력
# Out:
# [<span class="blind">NAVER whale</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>]

# %%
soup.find_all('span', class_=['blind',"ico_arr"])[5:10] # span태그 중에서 클래스가 blind, ico_arr
# Out:
# [<span class="blind">한글 입력기</span>,
#  <span class="blind">자동완성 레이어</span>,
#  <span class="ico_arr"></span>,
#  <span class="blind">쇼핑</span>,
#  <span class="blind">쇼핑LIVE</span>]

# %%
soup.find_all('span',attrs={'class':'blind'})[0:11]
# Out:
# [<span class="blind">NAVER whale</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>,
#  <span class="blind">검색</span>,
#  <span class="blind">한글 입력기</span>,
#  <span class="blind">자동완성 레이어</span>,
#  <span class="blind">쇼핑</span>,
#  <span class="blind">쇼핑LIVE</span>,
#  <span class="blind">리스트형</span>,
#  <span class="blind">썸네일형</span>]

# %%
soup.find_all(string='네이버')
# Out:
# ['네이버']

# %%
# 정규표현식
print(soup.find_all(string = re.compile('네이버'))) # 네이버 들어간거 모두 찾기

# %%
req = requests.get("http://movie.naver.com")
html = req.text
# print(html)
soup = BeautifulSoup(html,'html.parser')
text = soup.find('span', attrs={'class':'blind'}) # attrs는 dict로 되어 있다. dict로 적용해야 원하는 요청을 리턴할 수 있음
print(text)  # span 태그에 클래스명 blind인것 출력
print(text.get_text()) # 태그사이에 있는 내용 출력
print(text.get('class')) # 클래스명 찾기
# Out:
# <span class="blind">영화검색 영역</span>
# 영화검색 영역
# ['blind']

# %%
html = """
<html><body>
<div id="meigen">
  <h1>위키북스 도서</h1>
  <ul class="items">
    <li>유니티 게임 이펙트 입문</li>
    <li>스위프트로 시작하는 아이폰 앱 개발 교과서</li>
    <li>모던 웹사이트 디자인의 정석</li>
  </ul>
</div>
</body></html>
"""

soup = BeautifulSoup(html,'html.parser')
h1 = soup.select_one('div#meigen > h1').string # select_one 하나만 선택--> find랑 같음
h1 # div태그의 아이디가 meigen의 자식 h1태그의 string
# Out:
# '위키북스 도서'

# %%
# BeautifulSoup(요청결과의 내용, '파싱할 대상 type(html, xml, json)' , 인코딩타입)
soup = BeautifulSoup(html,'html.parser')
li = soup.select('div#meigen >ul.items> li')
for i in li: # li가 3개이므로 for문 돌려서 출력해줘야함
    print(i.string)
# Out:
# 유니티 게임 이펙트 입문
# 스위프트로 시작하는 아이폰 앱 개발 교과서
# 모던 웹사이트 디자인의 정석

# %%
li = soup.select("div#meigen > ul > li") # ul이 하나이므로, items 안붙여줘도 가능
for i in li:
    print(i.string)
# Out:
# 유니티 게임 이펙트 입문
# 스위프트로 시작하는 아이폰 앱 개발 교과서
# 모던 웹사이트 디자인의 정석

# %%
items = soup.select('div#meigen > ul.items > li')
for li in items:
    print(li.string) # li.text도 가능함
# Out:
# 유니티 게임 이펙트 입문
# 스위프트로 시작하는 아이폰 앱 개발 교과서
# 모던 웹사이트 디자인의 정석

# %%
# Q. 네이버 환율(원화/USD) 가져오기

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://finance.naver.com/marketindex/'
html = requests.get(url).text
s = BeautifulSoup(html,'html.parser')
a = s.findAll('span', class_=['value']) # <span> 태그에 class명이 value인것 찾기 -> find 하나만 리턴됨
for i in a:
    print(f'{i.text}', end='\n') 
# print('usd/krw = ',a.string)
# Out:
# 1,199.50
# 1,039.20
# 1,361.55
# 188.49
# 115.9100
# 1.1390
# 1.3570
# 96.0700
# 93.1
# 1708.23
# 1840.8
# 70260.69

# %%
import urllib.request as req

url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)

soup = BeautifulSoup(res,'html.parser')

# id : exchangeList il태그의 class가 on > a태그의 class가 head usd
price = soup.select_one('#exchangeList > li.on > a.head.usd > div >span.value').string
print('usd/krw = ', price)
# Out:
# usd/krw =  1,199.50

# %%
# 3, 6, 9, 12 번째(3의배수) 배경변경 
li:nth-child(3n){ background: red; } 
    
#10번째 부터 이후 모든 리스트 컬러변경 
li:nth-child(n+10) { color: blue; } 

# 1번째 부터 5번째 까지 배경변경 
li:nth-child(-n+5) { background: green; }
    
# 15번째 부터 20번째 까지 배경변경 
li:nth-child(n+15):nth-child(-n+20) { background: hotpink; } 
        
# 끝에서 부터 3번째 
li:nth-last-child(3) { background: gold; } 
    
# 홀수 
li:nth-child(odd) { color: red; } 
    
#짝수  
li:nth-child(even) { color: red; }

# %%
import urllib.request as req
 
url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)

soup = BeautifulSoup(res,'html.parser')

                            # #exchangeList > li.on > a.head.eur > div > span.value -> copy selector
price = soup.select_one('#exchangeList > li:nth-child(3) > a.head.eur > div > span.value').string

print('eur/krw =', price) # <span class="value">1,361.55</span> -> copy element
# Out:
# eur/krw = 1,361.55

# %%
# [과제] 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요

# %%
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&date=20220208'
res = requests.get(url).text
# print(res) string 타입으로 가져오기
soup = BeautifulSoup(res, 'html.parser')
#old_content > table > tbody > tr:nth-child(2) > td.title > div > a
movie_top1 = soup.select_one('div.tit3 > a') # 하나만 선택
movie_top1.text
# Out:
# '해적: 도깨비 깃발'

# %%
# [과제] 네이버 영화 랭킹 가져와서 전체 영화제목을 출력하세요
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cnt&date=20220208'
res = requests.get(url).text 
soup = BeautifulSoup(res, 'html.parser')
movie_top = soup.select('#old_content > table > tbody > tr> td.title> div> a')
for i, m in enumerate(movie_top): # key, value 형식으로 출력
    print(f'No.{i+1} : {m.text}')
# Out:
# No.1 : 해적: 도깨비 깃발
# No.2 : 킹메이커
# No.3 : 특송
# No.4 : 스파이더맨: 노 웨이 홈
# No.5 : 나일 강의 죽음
# No.6 : 하우스 오브 구찌
# No.7 : 씽2게더
# No.8 : 경관의 피
# No.9 : 355
# No.10 : 어나더 라운드
# No.11 : 언차티드
# No.12 : 극장판 안녕 자두야: 제주도의 비밀
# No.13 : 듄
# No.14 : 드라이브 마이 카
# No.15 : 미싱타는 여자들
# No.16 : 킹스맨: 퍼스트 에이전트
# No.17 : 셰터드
# No.18 : 나의 촛불
# No.19 : 인민을 위해 복무하라
# No.20 : 수퍼모델
# No.21 : 만년이 지나도 변하지 않는 게 있어
# No.22 : 짬뽕비권
# No.23 : 나이트메어 앨리
# No.24 : 트로트는 인생이다
# No.25 : 창극 변강쇠 점 찍고 옹녀
# No.26 : 강릉
# No.27 : 더 배트맨
# No.28 : 인질
# No.29 : 장민호 드라마 최종회
# No.30 : 인어가 잠든 집
# No.31 : 효자
# No.32 : 삼진그룹 영어토익반
# No.33 : 캐시트럭
# No.34 : 블랙머니
# No.35 : 극장판 주술회전 0
# No.36 : 레지던트 이블: 라쿤시티
# No.37 : 프랑스
# No.38 : 굿 보스
# No.39 : 안테벨룸
# No.40 : 코로나
# No.41 : 웨스트 사이드 스토리
# No.42 : 가슴이 떨리는 건 너 때문
# No.43 : 문폴

# %%
# [과제] 기상청 육상 정보에서 강원도의 지역번호는 105이다. 강원도의 날씨예보를 출력하세요.
# url = 'https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105'

import re
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse
api = 'https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

values = {
    'stnId':'105'
}
params = urllib.parse.urlencode(values)
url = api + "?" + params
print("url", url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').string
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text

# %%
# [과제] 관심 내용에 대하여 웹에서 가져와서 정규표현식, BS를 이용하여 데이터를 출력하세요.

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""
soup = BeautifulSoup(html,'html.parser')
contents = soup.find('body')
contents # body 태그 안에 있는 태그들 출력 -> bdoy포함
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>

# %%
# 자식 vs 자손
# for child in contents.children:
#     print(child)
for d in contents.descendants: #  contents는 body 태그 -> body의 자손들 -> <p>와 <div> 태그, <div> 안에 있는 <img>
    print(d)
# Out:
# <p align="center" class="a"> text1</p>
#  text1
#
#
# <p align="center" class="b"> text2</p>
#  text2
#
#
# <p align="center" class="c"> text3</p>
#  text3
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
#
#
# <img height="200" src="/source" width="300"/>

# %%
img_tag = contents.find('img')
print(img_tag,'\n')
print(img_tag.parent) # <img> 감싸고 있는 부모 <div> 태그까지 출력
# Out:
# <img height="200" src="/source" width="300"/>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
# 조상들 -> 복수
list(img_tag.parents)
# Out:
# [<div>
#  <img height="200" src="/source" width="300"/>
#  </div>,
#  <body>
#  <p align="center" class="a"> text1</p>
#  <p align="center" class="b"> text2</p>
#  <p align="center" class="c"> text3</p>
#  <div>
#  <img height="200" src="/source" width="300"/>
#  </div>
#  </body>,
#
#  <head>
#  <title>crawler</title>
#  </head>
#  <body>
#  <p align="center" class="a"> text1</p>
#  <p align="center" class="b"> text2</p>
#  <p align="center" class="c"> text3</p>
#  <div>
#  <img height="200" src="/source" width="300"/>
#  </div>
#  </body>
#  ]

# %%
print('**img_tag의 부모(body)**\n',img_tag.find_parent('body'), '\n')
print('**img_tag의 부모(div)**\n', img_tag.find_parent('div'))
# Out:
# **img_tag의 부모(body)**
#  <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# **img_tag의 부모(div)**
#  <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
p_tags = soup.find_all('p')
p_tags
# Out:
# [<p align="center" class="a"> text1</p>,
#  <p align="center" class="b"> text2</p>,
#  <p align="center" class="c"> text3</p>]

# %%
p_tag = soup.find_all('p',class_=['b','c'])
p_tag
# Out:
# [<p align="center" class="b"> text2</p>,
#  <p align="center" class="c"> text3</p>]

# %%
# p 태그중에서 class가 b,c인것 출력
p_tag = soup.find_all('p', attrs ={'class': {'b','c'}}) 
p_tag
# Out:
# [<p align="center" class="b"> text2</p>,
#  <p align="center" class="c"> text3</p>]

# %%
# 부모 다루기 
# 앞에 있는 형제 요소를 선택하기 위해서는 previous_sibling
import requests
import re
from bs4 import BeautifulSoup
url = 'https://www.pythonscraping.com/pages/page3.html'
url_req = requests.get(url)
html = url_req.text
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('img',  
             {'src':'../img/gifts/img1.jpg'}).parent.previous_sibling.string) # img부모태그 -> td의 이전 형제
# Out:
# $15.00

# %%
url = 'https://www.pythonscraping.com/pages/page3.html'
req = requests.get(url)
html = req.text
soup = BeautifulSoup(html,'html.parser')
img = soup.select_one('#gift5 > td:nth-child(4) > img') # id가 gift5 중에서 4번째 인덱스의 img 선택
print(img)
print(img.parent.previous_sibling.string) # img6의 부모 태그 -> td 의 이전 형제 태그 -> <td> $1.50 </td>
# Out:
# <img src="../img/gifts/img6.jpg"/>
#
# $1.50

# %%
html = requests.get('https://naver.com')
html = html.text
bs = BeautifulSoup(html, 'html.parser')

hlists = bs.findAll({'h1','h2','h3','h4','h5','h6'})
for h in hlists:
    print(h,'\n')
# Out:
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
#
# <h2 class="blind">뉴스스탠드</h2>
#
# <h2 class="blind">주제별 캐스트</h2>
#
# <h2 class="blind">Sign in</h2>
#
# <h2 class="blind">타임스퀘어</h2>
#
# <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3>
#
# <h3 class="title">Creators</h3>
#
# <h3 class="title">Partners</h3>
#
# <h3 class="title">Developers</h3>
#
# <h3 class="blind">네이버 정책 및 약관</h3>

# %%
hlists = bs.find({'h1','h2','h3','h4','h5','h6'}, text='뉴스스탠드')
hlists.string
# Out:
# '뉴스스탠드'

# %%
ttls = bs.findAll(id = 'NM_NEWSSTAND_TITLE')
for t in ttls:
    print(t.text)
# Out:
#  뉴스스탠드  구독한 언론사 전체언론사    리스트형  썸네일형  설정

# %%
url = 'https://www.dataq.or.kr/www/sub/a_07.do'
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <title>
#    데이터자격시험
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <!-- 캐시 방지 -->
#   <meta content="No-Cache" http-equiv="Pragma">
#    <meta content="no-cache; must-revalidate; no-store" http-equiv="Cache-Control">
#     <meta content="now" http-equiv="Expires">
#      <link href="/www/css/iosys-front.css?v=500021" rel="stylesheet" type="text/css"/>
#      <link href="/www/css/iosys-fix.css?v=500021" rel="stylesheet" type="text/css"/>
#      <script src="/www/js/plugins/jquery.js?v=500021" type="text/javascript">
#      </script>
#      <script src="/www/js/plugins/jquery-ui.js?v=500021" type="text/javascript">
#      </script>
#      <script src="/www/js/plugins/lodash.js?v=500021" type="text/javascript">
#      </script>
# ...

# %%
# 가장 첫 번째 결과를 반환하는 select_one()은 find()에, 
# 전체 결과를 리스트로 반환하는 select()는 find_all()에 대응한다.

# texts = soup.findAll(id='tab1')
texts = soup.select('#tab1') # select는 전체 결과를 리스트로 반환하기 때문에 for문으로 돌려줘야함
# print(texts)
for t in texts:
    print(t.text)
# Out:
# 국가기술자격
#
#
# 관련 근거
#
# 국가기술자격법 및 동법 시행령
#
#
#
# 빅데이터분석기사 정의
#
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
#
#
#
# 빅데이터분석기사의 필요성
#
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
#
#
#
# 빅데이터분석기사의 직무
#
# 대용량의 데이터 집합으로부터 유용한 정보를 찾고 결과를 예측하기 위해 목적에 따라 분석기술과 방법론을 기반으로 정형/비정형 대용량 데이터를 구축, 탐색, 분석하고 시각화를 수행하는 업무를 수행한다.

# %%
html = requests.get('https://www.dataq.or.kr/www/sub/a_07.do').text
soup = BeautifulSoup(html, 'html.parser')

a = soup.find(id='tab1').text
print(a)
print(re.sub('\n\n', '', a)) # 개행문자들을 공백처리한다
# Out:
# 국가기술자격
#
#
# 관련 근거
#
# 국가기술자격법 및 동법 시행령
#
#
#
# 빅데이터분석기사 정의
#
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
#
#
#
# 빅데이터분석기사의 필요성
#
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
#
#
#
# 빅데이터분석기사의 직무
#
# 대용량의 데이터 집합으로부터 유용한 정보를 찾고 결과를 예측하기 위해 목적에 따라 분석기술과 방법론을 기반으로 정형/비정형 대용량 데이터를 구축, 탐색, 분석하고 시각화를 수행하는 업무를 수행한다.
#
#
#
#
#
# 국가기술자격
# 관련 근거국가기술자격법 및 동법 시행령빅데이터분석기사 정의빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.빅데이터분석기사의 필요성전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# ...

# %%
# [과제] 아래와 같이 원본 데이터를 유지하면서 빈줄 없이 출력하세요.
국가기술자격
관련 근거
국가기술자격법 및 동법 시행령
빅데이터분석기사 정의
빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
빅데이터분석기사의 필요성

# %%
import re
import requests
from bs4 import BeautifulSoup

url = 'https://www.dataq.or.kr/www/sub/a_07.do'
html = requests.get(url).text
print(type(html)) # str형식임
bs1 = BeautifulSoup(html,'html.parser') # parsing해줌 html로

li = bs1.select_one('#tab1').text

li1 = re.sub('\n\n', '\n',li) # re.sub（정규 표현식, 대상 문자열 , 치환 문자)
print(li1)

li2 = re.sub('\n\n', '\n', li1)
print(li2)
# Out:
# <class 'str'>
# <class 'bs4.BeautifulSoup'>
#
# 국가기술자격
#
# 관련 근거
# 국가기술자격법 및 동법 시행령
#
# 빅데이터분석기사 정의
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
#
# 빅데이터분석기사의 필요성
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
#
# 빅데이터분석기사의 직무
# 대용량의 데이터 집합으로부터 유용한 정보를 찾고 결과를 예측하기 위해 목적에 따라 분석기술과 방법론을 기반으로 정형/비정형 대용량 데이터를 구축, 탐색, 분석하고 시각화를 수행하는 업무를 수행한다.
#
#
#
# 국가기술자격
# 관련 근거
# 국가기술자격법 및 동법 시행령
# 빅데이터분석기사 정의
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
# 빅데이터분석기사의 필요성
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
# 빅데이터분석기사의 직무
# ...

# %%
lis = bs1.findAll({'h3','h4','p'})
for l in lis[:11]:
    print(l.string)
# Out:
# 국가기술자격
# 관련 근거
# 국가기술자격법 및 동법 시행령
# 빅데이터분석기사 정의
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
# 빅데이터분석기사의 필요성
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
# 빅데이터분석기사의 직무
# 대용량의 데이터 집합으로부터 유용한 정보를 찾고 결과를 예측하기 위해 목적에 따라 분석기술과 방법론을 기반으로 정형/비정형 대용량 데이터를 구축, 탐색, 분석하고 시각화를 수행하는 업무를 수행한다.

# %%
# 전쟁과 평화
url = 'http://www.pythonscraping.com/pages/warandpeace.html'
html = requests.get(url).text
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())
# Out:
# <html>
#  <head>
#   <style>
#    .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
#   </style>
#  </head>
#  <body>
#   <h1>
#    War and Peace
#   </h1>
#   <h2>
#    Chapter 1
#   </h2>
#   <div id="text">
#    "
#    <span class="red">
#     Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.
#    </span>
#    "
#    <p>
#    </p>
#    It was in July, 1805, and the speaker was the well-known
#    <span class="green">
#     Anna
# Pavlovna Scherer
#    </span>
#    , maid of honor and favorite of the
# ...

# %%
d1 = bs.find(id='text')
# print(d1.text)
d2 = bs.findAll('span',{'class':{'red','green'}})
for i,d in enumerate(d2):
    print(f'No.{i+1} : \n {d.text}', '\n')
# Out:
# No.1 :
#  Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.
#
# No.2 :
#  Anna
# Pavlovna Scherer
#
# No.3 :
#  Empress Marya
# Fedorovna
#
# No.4 :
#  Prince Vasili Kuragin
#
# No.5 :
#  Anna Pavlovna
#
# No.6 :
#  St. Petersburg
#
# No.7 :
#  If you have nothing better to do, Count [or Prince], and if the
# prospect of spending an evening with a poor invalid is not too
# terrible, I shall be very charmed to see you tonight between 7 and 10-
# Annette Scherer.
#
# No.8 :
#  Heavens! what a virulent attack!
#
# No.9 :
#  the prince
#
# No.10 :
#  Anna Pavlovna
#
# ...

# %%
# Q. 전쟁과 평화에 등장하는 모든 고유명사을 출력하세요.

# %%
url = 'http://www.pythonscraping.com/pages/warandpeace.html'
url_req = requests.get(url).text
bs = BeautifulSoup(url_req,'html.parser')
# bs
d2 = bs.findAll('span',{'class':'green'})
# list(d2)

for d in d2:
    print(d.text)
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
url = 'http://www.pythonscraping.com/pages/warandpeace.html'
url_req = requests.get(url).text
bs = BeautifulSoup(url_req,'html.parser')
d2 = bs.findAll('span',{'class':'green'})

def check(text):
    checking = ('the','The','her','Her','his','His','its','Its')
    checking2 = ("'s")
    if text.startswith(checking) == False and text.endswith(checking2) == False:
        print(text)  # checking과 checking2 제외한 단어만 담김

for i in d2:
    i = i.text.replace('\n','')
    check(i)
# Out:
# AnnaPavlovna Scherer
# Empress MaryaFedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# Anna Pavlovna
# Anna Pavlovna
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# Prince Vasili
# Dowager Empress Marya Fedorovna
# Anna Pavlovna
# BaronFunke
# AnnaPavlovna
# Anatole
# AnnaPavlovna
# Anna Pavlovna

# %%
# 정규표현식 + bs4
url = 'http://www.pythonscraping.com/pages/page3.html'
html = requests.get(url).text
bs = BeautifulSoup(html, 'html.parser')

images =  bs.findAll('img')
list(images)
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
import re
html = requests.get(url).text
bs = BeautifulSoup(html, 'html.parser')

# images = bs.findAll('img', {'src':re.compile('\.\.\/img.*\.jpg')})
images = bs.findAll('img', {'src':re.compile('\.\.\/img.*jpg')})
for image in images:
    print(image['src'])
# Out:
# ../img/gifts/logo.jpg
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
# lambda 이용
spans = bs.findAll('span')
list(spans)
# Out:
# [<span class="excitingNote">Now with super-colorful bell peppers!</span>,
#  <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>,
#  <span class="excitingNote">Also hand-painted by trained monkeys!</span>,
#  <span class="excitingNote">Or maybe he's only resting?</span>,
#  <span class="excitingNote">Keep your friends guessing!</span>]

# %%
bs.find_all(lambda tag: tag.get_text() == "Or maybe he's only resting?")
# Out:
# [<span class="excitingNote">Or maybe he's only resting?</span>]

# %%
# Q. 가능한 모든 방법으로 Numbers를 출력하세요(10개 이상) 
fp = open('books.html', encoding='utf-8')
soup = BeautifulSoup(fp,'html.parser')
print(soup.prettify())
# Out:
# <ul id="bible">
#  <li id="ge">
#   Genesis
#  </li>
#  <li id="ex">
#   Exodus
#  </li>
#  <li id="le">
#   Leviticus
#  </li>
#  <li id="nu">
#   Numbers
#  </li>
#  <li id="de">
#   Deuteronomy
#  </li>
# </ul>

# %%
# 인덱싱
print(soup.select('li')[3].string) # 3번째 인덱스 0, 1, 2, 3
print(soup.find_all('li')[3].string) # 전체 결과를 리스트로 반환하는 select()는 find_all()
# Out:
# Numbers
# Numbers

# %%
# lambda 사용
import requests
import re
from bs4 import BeautifulSoup
sel = lambda q : print(soup.select_one(q).string)

sel('#nu') # io로 접근
sel('li#nu') # li의 id로 접근
sel('ul> li#nu') # ul 밑에 잇는 li의 id nu
sel('#bible #nu') # ul id 에서 li id
sel('#bible > #nu')
sel('ul#bible > li#nu')
sel("li[id='nu']") # "' '" 쉼표 주의
sel("li:nth-of-type(4)") # th-of-type의 경우 부모 요소의 모든 자식 요소 중 ①type 조건을 만족하고 ②순서를 만족하는 대상을 선택
# Out:
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers

# %%
print(soup.find(id = 'nu').text) # id값으로
print(soup.select('li')[3].text) # 인덱스로
print(soup.find('li',id='nu').text) 
print(soup.select_one('li#nu').text)
print(soup.find(lambda tag: tag.get_text()=='Numbers').text) # lambda사용
print(list(soup.find('ul').children)[2]) # 이해안감
# Out:
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers

# %% [markdown]
# ### urllib 모듈이란 : 파이썬의 표준 모듈로서 URL을 다루기 위한 모듈 패키지
# - 설치가 필요하지 않고 import urllib으로 활용
# - requests 모듈과 마찬가지로 URL과 관련된 여러가지 기능들을 제공(하위 모듈)
#     - request : URL을 열고 읽는 모듈(HTTP 요청)
#     - error : request 모듈에서 발생하는 에러들을 포함하는 모듈
#     - parse : URL을 파싱하는 모듈(URL 해석 및 조작)
#     - robotparser : robots.txt 파일을 파싱하는 모듈

# %%
import urllib

url = 'https://www.naver.com'
request = urllib.request.Request(url)
print(request)
print(request.full_url)
print(request.type)
print(request.host)
# Out:
# ...
# https://www.naver.com
# https
# www.naver.com

# %%
response1 = urllib.request.urlopen(request)
print(response1,'\n')
print(response1.geturl,'\n')
print(response1.getheaders(),'\n')
# Out:
# ...
#
# <bound method HTTPResponse.geturl of <http.client.HTTPResponse object at 0x000001F4284F46D0>>
#
# [('Server', 'NWS'), ('Date', 'Sun, 13 Feb 2022 13:24:39 GMT'), ('Content-Type', 'text/html; charset=UTF-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('Set-Cookie', 'PM_CK_loc=c32a5daaed405976e4bc8b6fd514ba417db8b8704822d45c80c883392a18d00a; Expires=Mon, 14 Feb 2022 13:24:39 GMT; Path=/; HttpOnly'), ('Cache-Control', 'no-cache, no-store, must-revalidate'), ('Pragma', 'no-cache'), ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"'), ('X-Frame-Options', 'DENY'), ('X-XSS-Protection', '1; mode=block'), ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains'), ('Referrer-Policy', 'unsafe-url')]

# %%
# read() : 인자로 전달한 숫자만큼 바이트 기준으로 데이터를 읽음
response2 = urllib.request.urlopen(url)
response2.read(500).decode('utf-8')  # requests.get(url).text 와 같음
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m'

# %%
# urllib.request.urlretrieve() : 웹상의 이미지 저장
import urllib.request
img_src = 'https://images.unsplash.com/photo-1536329583941-14287ec6fc4e?ixlib=rb-1.2.1&ixid=MnwxMjA3fDF8MHxlZGl0b3JpYWwtZmVlZHwxfHx8ZW58MHx8fHw%3D&auto=format&fit=crop&w=500&q=60'
new_name = 'img.png'
urllib.request.urlretrieve(img_src,new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x1f4282c78e0>)

# %%
# 단순한 패턴을 읽을 때에는 복잡한 정규표현식보다는 간단한 parse 모듈을 사용
# urllib.parse : URL을 6개로 분리하여 반환
import urllib

# urllib.parse.urlparse 를 사용하여 url를 ParseResult 객체로 가져올 수 있습니다.
parse = urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')

# ParseResult 객체의 각 값들을 위와같이 가져올 수 있습니다.
print(parse,'\n')
print(parse[0])
print(parse.scheme,'\n')

print(parse[1])
print(parse.netloc,'\n')

print(parse[2])
print(parse.path,'\n')

print(parse[3])
print(parse.params,'\n')

print(parse[4])
print(parse.query,'\n')

print(parse[5])
print(parse.fragment,'\n')
# Out:
# ParseResult(scheme='https', netloc='section.blog.naver.com', path='/Search/Post.naver', params='', query='pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', fragment='')
#
# https
# https
#
# section.blog.naver.com
# section.blog.naver.com
#
# /Search/Post.naver
# /Search/Post.naver
#
#
#
#
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai

# %%
# urllib.parse.urlunparse(), urllib.parse.urlunsplit()
# 튜플(변경 불가능)로 반환되기 때문에 리스트(변경 가능)로 변경하여 활용

parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)
parse = list(parse)
parse[1]= 'blog.daum.net'
parse
unparse = urllib.parse.urlunparse(parse)
print(unparse)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
# https://blog.daum.net/koreatech91;a=1?b=2#b

# %%
# parse_qs(), pars_qsl()
# 쿼리를 파싱해서 사전(qs) 및 리스트(qsl)로 반환, 쿼리를 변경하여 요청시 활용
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse.query)
qs = urllib.parse.parse_qs(parse.query)
print(qs, type(qs))
qsl = urllib.parse.parse_qsl(parse.query)
print(qsl, type(qsl))
# Out:
# b=2
# {'b': ['2']} <class 'dict'>
# [('b', '2')] <class 'list'>

# %%
# urljoin(a,b) : a와 b url을 합쳐주는 기능 -> '/'에 따라 url 주소가 달라짐
url = 'https://naver.com/a/b'
print(urllib.parse.urljoin(url,'c'))
print(urllib.parse.urljoin(url,'/c'))
# Out:
# https://naver.com/a/c
# https://naver.com/c

# %%
 # quote(), unquote() : 아스키코드가 아닌 퍼센트 인코딩으로 변환
# 퍼센트 인코딩은 url에 문자를 표현하는 문자 인코딩 방법
# url에 한글이 섞이면 오류 발생

print(urllib.parse.quote('파이썬'))
print(urllib.parse.unquote('%ED%8C%8C%EC%9D%B4%EC%8D%AC'))
# Out:
# %ED%8C%8C%EC%9D%B4%EC%8D%AC
# 파이썬

# %%
# url = 'https://search.naver.com/search.naver?query="파이썬"'
url = 'https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

response = urllib.request.urlopen(url)
byte_data = response.read(100)
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always

# %%
# 홈페이지를 로컬에 파일로 저장
request = urllib.request.Request('https://www.naver.com')
data = urllib.request.urlopen(request).read()
f = open('pc.html','wb')
f.write(data)
f.close()

# %%
with open('pc.html','rb') as f:
    data = f.read().decode('utf-8')
    print(data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
query_list =['파이썬', '웹 크롤링', '빅데이터', 'python']
url = 'https://search.naver.com/search.naver?query='
for i in query_list:
    new_url = url + urllib.parse.quote(i)
    response_urllib = urllib.request.urlopen(new_url)
    byte_data = response_urllib.read(400)
    text_data = byte_data.decode('utf-8')
    print(text_data,'\n')
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="파이썬 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/ss
#
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="웹 크롤링 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.ne
#
# ...
